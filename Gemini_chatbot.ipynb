# %%
pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.6.15)

# %%
import google.generativeai as genai

genai.configure(api_key= 'AIzaSyD2XX0QGCGUyDr3iKLsrSxjItHqBPK_aOE')

model= genai.GenerativeModel('models/gemini-1.5-flash')

chat= model.start_chat(history=[])

print('Welcome to Gemini Chatbot- Sourav! Type "exit" to end the conversation')

while True:
  user_input= input("Sourav:  ")
  if user_input.lower()== 'exit':
    break
  try:
    response= chat.send_message(user_input)
    print(f'Gemini: {response.text}')
  except Exception as e:
    print(f'An error occurred: {e}')

print('Chatbot session ended')
# Out:
# Welcome to Gemini Chatbot- Sourav! Type "exit" to end the conversation
# Sourav:  best vandal skin valorant
# Gemini: There's no single "best" Vandal skin in Valorant, as the best skin is entirely subjective and depends on individual preferences.  Different players value different things, such as:
#
# * **Visuals:** Some players prioritize skins with unique animations, sound effects, or overall aesthetic appeal.
# * **Price:**  Some prefer free or less expensive skins, while others are willing to pay more for premium options.
# * **Level of detail:**  Some players prefer highly detailed skins, while others prefer simpler designs.
#
# However, some popular and highly-rated Vandal skins frequently mentioned include:
#
# * **Prime Vandal:** A classic and consistently popular choice for its clean and sleek design.
# * **Oni Vandal:**  Known for its striking and visually impressive design, though some find the animations a bit over-the-top.
# * **Elderflame Vandal:**  Another highly popular choice, but is significantly more expensive due to its intricately detailed design and impressive animations.  It is regarded as one of the best overall skins in Valorant.
# * **Reaver Vandal:**  A darker, more menacing skin with unique animations.
#
# Ultimately, the best Vandal skin for you depends on your taste and budget.  Checking out videos and in-game previews of different skins is the best way to find one that appeals to you.  Looking at websites and forums dedicated to Valorant will also give you a sense of community preferences.
#
# Sourav:  i have budget of 2100vp what should i buy
# Gemini: With 2100 VP in Valorant, you have several options depending on your priorities:
#
# * **One Premium Bundle:**  Many premium bundles cost around 2100 VP, and this is the most straightforward way to use your VP.  These bundles usually include a Vandal skin (or other weapon skins), a player card, a spray, and sometimes other cosmetics.  Look at the current store to see what bundles are available that appeal to your style.
#
# * **One Premium Skin + Extras:** You could purchase a single premium Vandal skin (some cost around 1775 VP), leaving you with enough VP for a smaller item like a gun buddy or spray.
#
# * **Several Premium Weapon Skins (Lower Tier):** You might find multiple weapon skins at lower price points (e.g., 875 VP each) that you could combine to spend your VP.  This would give you a variety of cosmetic items but not as visually striking as a single premium bundle or skin.
#
# * **A combination of the above:** You can mix and match your purchases. Maybe a mid-tier weapon skin (around 1275 VP) and some smaller cosmetics.
#
#
# **Before you buy:**
#
# * **Check the in-game store regularly:** The Valorant store rotates its offerings, so the available bundles and skins change frequently.  Wait for a bundle you really like rather than settling for something you are not as excited about.
# * **Watch reviews and gameplay videos:** YouTube is a great resource for seeing how skins look and sound in-game.  This helps you decide if the animations and visual effects suit your preferences.
# * **Consider what you value most:**  Do you prioritize a single high-quality skin, or multiple lower-priced options?
# * **Don't feel pressured:** Don't spend your VP unless you find something you genuinely want.  You can save it for a future bundle or skin that better suits your tastes.
#
# Ultimately, the best way to spend your 2100 VP is to browse the in-game store and choose what appeals to *you* most.
#
# Sourav:  if you would have to rank operator skin what would it be
# Gemini: Ranking Operator skins is tricky because it's highly subjective, depending on what aspects you prioritize (visuals, animations, sound effects, etc.).  However, if I had to create a *potential* ranking based on community perception and general quality,  it would look something like this (note: this is a *possible* ranking and others might disagree).  This ranking also assumes we are only considering *premium* Operator skins and not the standard ones:
#
#
# **Tier 1 (Top Tier):**
#
# * **Possibly a future skin:**  New skins are frequently released, and a truly outstanding one could easily top this list.  The meta for best skins changes.
#
# **Tier 2 (Excellent):**
#
# * Skins with highly detailed and unique animations:  Many high-tier skins excel here, but pinpointing one specific skin without knowing your personal preferences is difficult.  Look for those with elaborate VFX and satisfying reload animations.
#
# **Tier 3 (Good):**
#
# * Skins with decent visuals and animations but without the "wow" factor of Tier 2:  These are still quality skins, but may lack the unique visual flair or polished animations of the top tier.  Often, they have a nice color scheme or a cohesive design language.
#
#
# **Important Considerations:**
#
# * **Personal Preference:**  The "best" skin is ultimately a matter of personal taste.  What one person finds visually appealing, another might dislike.
# * **Rarity and Price:**  More expensive skins aren't automatically better.  A lower-priced skin might have a visual style you appreciate more than a premium option.
# * **Ongoing Releases:**  New Operator skins are continuously released, so any ranking will be temporary.
#
#
# To find the best Operator skin *for you*, I recommend browsing the in-game store, watching videos and reviews on YouTube, and reading community discussions on Valorant forums or subreddits. This will give you a better idea of what skins appeal to you most.
#
# Sourav:  who is the current ipl winner
# Gemini: The current IPL (Indian Premier League) winner is the **Gujarat Titans**.  They won the IPL 2023 tournament.
#
# Sourav:  2024
# Gemini: The IPL 2024 winner has not yet been determined as the tournament hasn't happened yet.  The tournament typically takes place in the spring of each year.
#
# Sourav:  exit
# Chatbot session ended
